# %% [markdown]
# ## This notebook is an assignment to enhance the strength of the rainbow in a picture that has a rainbow.

# %%
import sys 

sys.path.append('..')

import my_cv

# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# loading the picture 
rainbow = cv2.imread('../rainbow.jpg', 1)
plt.imshow(rainbow)
